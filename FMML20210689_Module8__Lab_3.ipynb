# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-24 16:37:30--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   158MB/s    in 0.4s
#
# 2022-06-24 16:37:31 (158 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 620    1608.00466v2  The state-of-the-art CNN models give good perf...    cs
# 21513   0806.4115v4  We propose a new sparsity-smoothness penalty f...  stat
# 6113   1607.06364v1  Distributed learning is the problem of inferri...  stat
# 22391  1605.05918v2  Sparse versions of principal component analysi...  stat
# 39826  1705.08983v2  Regularized inversion methods for image recons...    cs
# ...             ...                                                ...   ...
# 7703   1802.09246v2  Variable selection is central to high-dimensio...  stat
# 8459   1609.09199v1  In this paper, we propose a supervised diction...    cs
# 9784    0805.2027v2  Several researchers have recently investigated...    cs
# 22172  1506.04725v1  We propose a class of nonparametric two-sample...  stat
# 39571  1609.04855v2  Microtask crowdsourcing is increasingly critic...    cs
#
#                                                    title  year  \
# 620    Learning Semantically Coherent and Reusable Ke...  2016
# 21513                 High-dimensional additive modeling  2008
# 6113   Distributed Supervised Learning using Neural N...  2016
# 22391  Bayesian Variable Selection for Globally Spars...  2016
# 39826  Plug-and-Play Unplugged: Optimization Free Rec...  2017
# ...                                                  ...   ...
# 7703   Scalable kernel-based variable selection with ...  2018
# 8459   Structure-Aware Classification using Supervise...  2016
# 9784       Rollout Sampling Approximate Policy Iteration  2008
# 22172  Fast Two-Sample Testing with Analytic Represen...  2015
# 39571  A Glimpse Far into the Future: Understanding L...  2016
#
#                                                 keywords
# 620    [performance, classification, empirically, des...
# 21513  [smoothness, dimensional, generalized, combina...
# 6113   [distributed, inferring, distributed, geograph...
# 22391  [principal, component, themselves, selecting, ...
# 39826  [regularized, inversion, reconstruction, tract...
# ...                                                  ...
# 7703   [selection, dimensional, algorithms, developed...
# 8459   [supervised, dictionary, algorithm, dimensions...
# 9784   [researchers, investigated, connection, reinfo...
# 22172  [nonparametric, distances, functions, represen...
# 39571  [microtask, crowdsourcing, increasingly, extre...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 620      [performance, classification, empirically, des...
# 21513    [smoothness, dimensional, generalized, combina...
# 6113     [distributed, inferring, distributed, geograph...
# 22391    [principal, component, themselves, selecting, ...
# 39826    [regularized, inversion, reconstruction, tract...
#                                ...
# 33687    [increasing, complexity, computing, reliabilit...
# 8869     [automatically, extracting, randomised, contro...
# 6119     [engineering, bottleneck, predictive, electron...
# 17013    [realistic, bottleneck, deception, detection, ...
# 5731     [algorithm, regression, dimensions, measuremen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8845 words.
# Out of those 4572 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8e2c9eae-74c7-493e-95ae-70b9ccde0bb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e2c9eae-74c7-493e-95ae-70b9ccde0bb4")) {                    Plotly.newPlot(                        "8e2c9eae-74c7-493e-95ae-70b9ccde0bb4",                        [{"x":["semantically","attention","properties","convolution","benchmark","leveraging","classification","experimental","motivated","explaining","additional","usefulness","efficient","reusability","demonstrate","coherence","preferable","technique","achieving","knowledge","clustering","explanation","empirically","interpretable","representation","desirable","mechanism","sentiwordnet","performance","observation","visualize","estimator","smoothness","generalized","numerical","optimality","likelihood","penalized","combination","furthermore","optimizing","algorithm","convergence","asymptotic","mathematical","computationally","dimensional","different","presented","designing","stochastically","horizontally","distributed","particularly","extensive","algorithms","extensions","communication","protocols","subsequently","authority","recurrent","sequential","vertically","throughout","discussion","introduced","strategies","nonlinear","architectures","applications","computational","centralized","introduce","beginning","summarized","definition","neighboring","requirements","processes","separated","geographically","practical","relatively","unlabeled","partitioned","restricted","diffusion","supervised","regression","inferring","computation","expectation","principal","separately","selecting","component","microarray","unsupervised","components","variational","drawbacks","selection","variables","illustrated","maximization","relaxation","difficult","particular","interpreted","synthetic","practitioner","procedure","maximized","themselves","framework","interpretation","probabilistic","traditional","expressiveness","reconstruction","regularizing","consensus","illustrate","operators","contribution","generalizes","tractability","equations","regularizers","denoisers","denoising","approached","preconditioning","convergent","conditions","individually","developed","regularity","including","expressible","convolutional","inversion","formulation","optimization","formulate","estimation","derivation","regularized","equilibrium","important","limitations","reconfigurations","psychologically","simultaneously","therefore","complexity","integrates","established","interaction","opponents","theoretic","modelling","generalise","inherently","solutions","techniques","psychology","intelligence","generalised","artefacts","constructed","artificial","detection","multithumos","outperforms","significantly","parameters","efficiently","structure","experiments","illustrating","intervals","backpropagation","hierarchy","differentiable","convolutions","continuous","treatment","probability","fundamental","confounders","completeness","observational","adjusting","identification","corollaries","covariates","inference","graphical"],"y":[33,192,177,54,195,45,491,402,53,18,109,30,383,3,564,20,4,235,84,342,121,24,70,36,343,32,105,2,921,61,9,31,21,76,89,11,61,2,134,157,41,806,125,15,52,88,191,772,198,50,1,1,112,76,174,572,38,79,12,28,3,162,88,1,22,20,139,92,63,111,398,294,8,347,6,6,47,15,54,115,8,2,150,62,35,6,44,22,201,132,24,132,32,28,29,35,85,1,142,91,63,19,144,122,16,33,18,118,256,18,124,1,119,6,22,540,56,153,189,9,109,7,16,64,49,65,33,9,28,8,4,43,5,4,12,149,14,198,8,250,1,398,10,81,280,64,209,9,41,22,343,70,2,2,129,125,235,24,52,86,3,45,54,5,19,170,372,13,80,8,3,47,140,355,2,268,282,249,168,316,575,9,12,20,36,27,14,104,29,170,81,0,12,6,6,111,1,1,208,34],"type":"bar"},{"x":["semantically","attention","properties","convolution","benchmark","leveraging","cla ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4572,), (4572, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7883333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Evaluating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style=''>Dutch</span> <span style=''>Word</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Embeddings</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.9506172839506173);'>Linguistic</span> <span style=''>Resource</span> <br/><br/><span style=''>Word</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style=''>have</span> <span style=''>recently</span> <span style=''>seen</span> <span style=''>a</span> <span style=''>strong</span> <span style=''>increase</span> <span style=''>in</span> <span style=''>interest</span> <span style=''>as</span> <span style=''>a</span> <span style=''>result</span> <span style=''>of</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>gains</span> <span style=''>on</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>tasks</span> <span style=''>However</span> <span style=''>most</span> <span style=''>of</span> <span style=''>this</span> <span style=''>research</span> <span style=''>also</span> <span style=''>underlined</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3541666666666666);'>benchmark</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulty</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructing</span> <span style=''>these</span> <span style=''>for</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>language</span> <span style=''>specific</span> <span style=''>tasks</span> <span style=''>Still</span> <span style=''>many</span> <span style=''>of</span> <span style=''>the</span> <span style=''>datasets</span> <span style=''>used</span> <span style=''>in</span> <span style=''>these</span> <span style=''>tasks</span> <span style=''>could</span> <span style=''>prove</span> <span style=''>to</span> <span style=''>be</span> <span style=''>fruitful</span> <span style='background-color:rgba(0, 255, 0, 0.9506172839506173);'>linguistic</span> <span style='background-color:rgba(0, 255, 0, 0.47619047619047616);'>resources</span> <span style=''>allowing</span> <span style=''>for</span> <span style=''>unique</span> <span style='background-color:rgba(255, 0, 0, 0.30041152263374493);'>observations</span> <span style=''>into</span> <span style=''>language</span> <span style=''>use</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variability</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style=''>created</span> <span style=''>with</span> <span style=''>both</span> <span style=''>count</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>architectures</span> <span style=''>on</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>corpora</span> <span style=''>in</span> <span style=''>two</span> <span style=''>language</span> <span style=''>specific</span> <span style=''>tasks</span> <span style=''>relation</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Algebraic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Geometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparison</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributions</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algebraic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>treating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>by</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cumulants</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>mean</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>As</span> <span style=''>an</span> <span style=''>example</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>finding</span> <span style=''>the</span> <span style=''>subspace</span> <span style=''>on</span> <span style=''>which</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>agree</span> <span style=''>Instead</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>involving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cumulants</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>by</span> <span style=''>treating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cumulants</span> <span style=''>as</span> <span style=''>elements</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>ring</span> <span style=''>we</span> <span style=''>can</span> <span style=''>directly</span> <span style=''>solve</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>at</span> <span style=''>a</span> <span style=''>lower</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>and</span> <span style=''>with</span> <span style=''>higher</span> <span style=''>accuracy</span> <span style=''>Moreover</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algebraic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>viewpoint</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>invoke</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algebraic</span> <span style=''>Geometry</span> <span style=''>which</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Simultaneously</span> <span style=''>Sparse</span> <span style=''>and</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Matrices</span> <br/><br/><span style=''>The</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.9215686274509804);'>penalized</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>aiming</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.31782945736434104);'>solutions</span> <span style=''>which</span> <span style=''>are</span> <span style=''>sparse</span> <span style=''>and</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>at</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>Such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>arise</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>social</span> <span style=''>networks</span> <span style=''>or</span> <span style=''>protein</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>graphs</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.52);'>adjacency</span> <span style=''>matrices</span> <span style=''>which</span> <span style=''>are</span> <span style=''>block</span> <span style=''>diagonal</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style=''>basis</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>convex</span> <span style=''>mixed</span> <span style=''>penalty</span> <span style=''>which</span> <span style=''>involves</span> <span style=''>ell</span> <span style=''>1</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>trace</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>We</span> <span style=''>obtain</span> <span style=''>an</span> <span style=''>oracle</span> <span style='background-color:rgba(255, 0, 0, 0.40740740740740755);'>inequality</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.4838709677419354);'>indicates</span> <span style=''>how</span> <span style=''>the</span> <span style=''>two</span> <span style=''>effects</span> <span style=''>interact</span> <span style='background-color:rgba(0, 255, 0, 0.452054794520548);'>according</span> <span style=''>to</span> <span style=''>the</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>matrix</span> <span style=''>We</span> <span style=''>bound</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>in</span> <span style=''>the</span> <span style=''>link</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>also</span> <span style=''>develop</span> <span style=''>proximal</span> <span style=''>descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strategies</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Very</span> <span style=''>Fast</span> <span style=''>Kernel</span> <span style=''>SVM</span> <span style=''>under</span> <span style=''>Budget</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Constraints</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>online</span> <span style=''>Kernel</span> <span style=''>SVM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>under</span> <span style=''>tight</span> <span style=''>budget</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>split</span> <span style=''>the</span> <span style=''>input</span> <span style=''>space</span> <span style=''>using</span> <span style=''>LVQ</span> <span style=''>and</span> <span style=''>train</span> <span style=''>a</span> <span style=''>Kernel</span> <span style=''>SVM</span> <span style=''>in</span> <span style=''>each</span> <span style=''>cluster</span> <span style=''>To</span> <span style=''>allow</span> <span style=''>for</span> <span style=''>online</span> <span style=''>training</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>limit</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>set</span> <span style=''>of</span> <span style=''>each</span> <span style=''>cluster</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>We</span> <span style=''>show</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiment</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>high</span> <span style=''>accuracy</span> <span style=''>while</span> <span style=''>having</span> <span style=''>a</span> <span style=''>very</span> <span style=''>high</span> <span style=''>number</span> <span style=''>of</span> <span style=''>samples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processed</span> <span style=''>per</span> <span style=''>second</span> <span style=''>both</span> <span style=''>in</span> <span style=''>training</span> <span style=''>and</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12119064493267187)
# 	evaluation (0.0995747696669029)
# 	architecture (0.08752657689581857)
# 	segmentation (0.07158043940467754)
# 	experimental (0.14245216158752658)
# 	information (0.25194897236002833)
# 	detection (0.12579730687455706)
# 	different (0.2735648476257973)
# 	convolutional (0.1410347271438696)
# 	recognition (0.13111268603827073)
#
# Some Statistics words are:
# 	optimization (0.18402426693629928)
# 	statistical (0.15267947421638017)
# 	variables (0.1430738119312437)
# 	theoretical (0.15925176946410516)
# 	estimation (0.18402426693629928)
# 	distribution (0.1845298281092012)
# 	algorithm (0.3988877654196158)
# 	dimensional (0.20222446916076844)
# 	inference (0.21183013144590496)
# 	regression (0.19514661274014156)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="26a326a9-23c4-45db-842e-808759aa7d34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26a326a9-23c4-45db-842e-808759aa7d34")) {                    Plotly.newPlot(                        "26a326a9-23c4-45db-842e-808759aa7d34",                        [{"x":["semantically","attention","properties","convolution","benchmark","leveraging","classification","experimental","motivated","explaining","additional","usefulness","efficient","reusability","demonstrate","coherence","preferable","technique","achieving","knowledge","clustering","explanation","empirically","interpretable","representation","desirable","mechanism","sentiwordnet","performance","observation","visualize","estimator","smoothness","generalized","numerical","optimality","likelihood","penalized","combination","furthermore","optimizing","algorithm","convergence","asymptotic","mathematical","computationally","dimensional","different","presented","designing","stochastically","horizontally","distributed","particularly","extensive","algorithms","extensions","communication","protocols","subsequently","authority","recurrent","sequential","vertically","throughout","discussion","introduced","strategies","nonlinear","architectures","applications","computational","centralized","introduce","beginning","summarized","definition","neighboring","requirements","processes","separated","geographically","practical","relatively","unlabeled","partitioned","restricted","diffusion","supervised","regression","inferring","computation","expectation","principal","separately","selecting","component","microarray","unsupervised","components","variational","drawbacks","selection","variables","illustrated","maximization","relaxation","difficult","particular","interpreted","synthetic","practitioner","procedure","maximized","themselves","framework","interpretation","probabilistic","traditional","expressiveness","reconstruction","regularizing","consensus","illustrate","operators","contribution","generalizes","tractability","equations","regularizers","denoisers","denoising","approached","preconditioning","convergent","conditions","individually","developed","regularity","including","expressible","convolutional","inversion","formulation","optimization","formulate","estimation","derivation","regularized","equilibrium","important","limitations","reconfigurations","psychologically","simultaneously","therefore","complexity","integrates","established","interaction","opponents","theoretic","modelling","generalise","inherently","solutions","techniques","psychology","intelligence","generalised","artefacts","constructed","artificial","detection","multithumos","outperforms","significantly","parameters","efficiently","structure","experiments","illustrating","intervals","backpropagation","hierarchy","differentiable","convolutions","continuous","treatment","probability","fundamental","confounders","completeness","observational","adjusting","identification","corollaries","covariates","inference","graphical","assumptions","conditioned","criterion","covariate","estimating","observing","considering","interesting","identifying","adjustment","reasonably","exploiting","introduces","collected","propagation","available","generated","information","constraints","robustness","supervisory","imbalance","specifically","constraint","neighborhood","researchers","symmetric","respective","verification","processing","generating","permitted","promising","accurately","containing","recognition","annotating","segmentation","encouraging","identified","connected","precision","competing","acquisition","theoretically","constrained","posteriori","aforementioned","distortion","outperform","estimated","outperformed","programming","noticeably","extraction","encou ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	confounders
# 	shattering
# 	heteroscedasticity
# 	frequentist
# 	elliptical
# 	approachable
# 	approachability
# 	underfitting
# 	sinusoidal
# 	discounting
# 	temperatures
# 	recasting
# 	projectorg
# 	diagnosed
# 	kantorovich
# 	regressionclassification
# 	nonparanormal
# 	cytometry
# 	microarrays
# 	metabolic
# Some words which never appear in Statistics papers:
# 	reusability
# 	sentiwordnet
# 	denoisers
# 	reconfigurations
# 	psychologically
# 	multithumos
# 	annotating
# 	multiword
# 	mandatory
# 	prospector
# 	descendant
# 	mismatched
# 	landmarks
# 	localizing
# 	recognizer
# 	recognizers
# 	reinforced
# 	accomplishing
# 	conversations
# 	invisible

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.049524274213223e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7408333333333333
